# %%
import cv2
import face_recognition

# %%
webcam_video=cv2.VideoCapture(0)
#initialize the array variable for storing the faces
number_of_faces=[]
#looping through every frame in the video
while True:
    #to get the current frame of video stream as an image
    ret,current_frame=webcam_video.read()
    #to resize the frame to 1/4 tp process faster
    resize_frame=cv2.resize(current_frame,(0,0),fx=0.25,fy=0.25)
    number_of_faces=face_recognition.face_locations(resize_frame,number_of_times_to_upsample=2,model='hog')
    for index,current_face_location in enumerate(number_of_faces):
        top_pos,right_pos,bottom_pos,left_pos=current_face_location
        top_pos=top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        print("found face  {} at top:{},right:{},bottom:{},left:{}".format(index+1,top_pos,right_pos,bottom_pos,left_pos))
        current_face_image = current_frame[top_pos:bottom_pos, left_pos:right_pos]
        current_face_image = cv2.GaussianBlur(current_face_image, (99,99), 30)
        current_frame[top_pos:bottom_pos, left_pos:right_pos] = current_face_image
        cv2.rectangle(current_frame, (left_pos,top_pos), (right_pos,bottom_pos), (0,0,255), 2)
    cv2.imshow("Webcam Video", current_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam_video.release()
cv2.destroyAllWindows()
# Out:
# found face  1 at top:224,right:304,bottom:372,left:152
# found face  1 at top:224,right:304,bottom:372,left:152
# found face  1 at top:276,right:632,bottom:480,left:416
# found face  1 at top:276,right:632,bottom:480,left:416
# found face  1 at top:252,right:632,bottom:468,left:416
# found face  2 at top:172,right:336,bottom:324,left:188
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:128,right:344,bottom:308,left:168
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:128,right:344,bottom:308,left:168
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  2 at top:204,right:632,bottom:420,left:416
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  2 at top:204,right:632,bottom:420,left:416
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:204,right:632,bottom:420,left:416
# found face  2 at top:124,right:336,bottom:272,left:188
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:128,right:344,bottom:308,left:168
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:128,right:344,bottom:308,left:168
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:124,right:336,bottom:272,left:188
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:124,right:320,bottom:272,left:172
# found face  1 at top:140,right:336,bottom:288,left:188
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:336,bottom:288,left:188
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:336,bottom:288,left:188
# found face  1 at top:140,right:336,bottom:288,left:188
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:140,right:320,bottom:288,left:172
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:228,right:632,bottom:444,left:416
# found face  2 at top:140,right:320,bottom:288,left:172
# found face  1 at top:140,right:304,bottom:288,left:152
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:108,right:324,bottom:288,left:148
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:108,right:324,bottom:288,left:148
# found face  2 at top:228,right:632,bottom:444,left:416
# found face  1 at top:108,right:324,bottom:288,left:148
# found face  1 at top:108,right:324,bottom:288,left:148
# found face  2 at top:208,right:640,bottom:388,left:464
# found face  1 at top:208,right:640,bottom:388,left:484
# found face  2 at top:108,right:344,bottom:288,left:168
# found face  1 at top:224,right:640,bottom:372,left:504
# found face  1 at top:224,right:640,bottom:372,left:504
# found face  1 at top:224,right:640,bottom:372,left:520
# found face  1 at top:224,right:640,bottom:372,left:520
# found face  1 at top:308,right:452,bottom:456,left:304
# found face  1 at top:324,right:436,bottom:472,left:288
# found face  1 at top:324,right:436,bottom:472,left:288
# found face  1 at top:272,right:468,bottom:424,left:320
# found face  1 at top:256,right:484,bottom:404,left:336
# found face  1 at top:248,right:504,bottom:428,left:324
# found face  1 at top:248,right:504,bottom:428,left:324
# found face  1 at top:248,right:504,bottom:428,left:324
# found face  1 at top:248,right:524,bottom:428,left:344
# found face  1 at top:256,right:520,bottom:404,left:368
