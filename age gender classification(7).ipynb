# %%
import cv2
import time
import face_recognition

# %%
webcam_video=cv2.VideoCapture(0)
time.sleep(3)
number_of_faces=[]

while True:
    ret,current_frame=webcam_video.read()
    resize_frame=cv2.resize(current_frame,(0,0),fx=0.25,fy=0.25)
    number_of_faces=face_recognition.face_locations(resize_frame,number_of_times_to_upsample=2,model='hog')
    for index,current_face_location in enumerate(number_of_faces):
        top_pos,right_pos,bottom_pos,left_pos=current_face_location
        top_pos=top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        print("Found face {} at top:{} , right:{} , bottom:{} , left:{}".format(index+1, top_pos, right_pos,
                                                                        bottom_pos, left_pos))
        current_face_image = current_frame[top_pos:bottom_pos, left_pos:right_pos]
        #The AGE_GENDER_MODEL_MEAN_VALUES from age_gender_mean.binaryproto using blob - 
        #blob.channel, blob.height, blob.weight
        AGE_GENDER_MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
        current_face_image_blob = cv2.dnn.blobFromImage(current_face_image, 1, (227,227), 
                                                        AGE_GENDER_MODEL_MEAN_VALUES, swapRB=False)
        #gender
        gender_list=['Male','Female']
        gender_protext="C:/Users/ASUS/Desktop/face recognition/datasets/gender_deploy.prototxt"
        gender_caffemodel="C:/Users/ASUS/Desktop/face recognition/datasets/gender_net.caffemodel"
        gender_model=cv2.dnn.readNet(gender_protext,gender_caffemodel)
        gender_model.setInput( current_face_image_blob)
        gender_prediction=gender_model.forward()
        gender = gender_list[gender_prediction[0].argmax()]
        
         #For age
        age_list = ['(0-2)','(4-6)','(8-12)','(15-20)','(25-32)','(38-43)','(48-53)','(60-100)']
        age_protext = "C:/Users/ASUS/Desktop/face recognition/datasets/age_deploy.prototxt"
        age_caffemodel = "C:/Users/ASUS/Desktop/face recognition/datasets/age_net.caffemodel"
        age_model = cv2.dnn.readNet(age_protext,age_caffemodel)
        age_model.setInput(current_face_image_blob)
        age_prediction = age_model.forward()
        age = age_list[age_prediction[0].argmax()]
        cv2.rectangle(current_frame, (left_pos,top_pos), (right_pos,bottom_pos), (0,0,255), 2)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(current_frame, gender+" "+age+"yrs", (left_pos,bottom_pos), font, 0.5, (255,255,255), 1)
        
    cv2.imshow("Webcam Video", current_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam_video.release()
cv2.destroyAllWindows()
# Out:
# Found face 1 at top:76 , right:388 , bottom:332 , left:128
# Found face 1 at top:160 , right:532 , bottom:420 , left:272
# Found face 1 at top:204 , right:488 , bottom:420 , left:272
# Found face 1 at top:180 , right:464 , bottom:396 , left:248
# Found face 1 at top:104 , right:500 , bottom:360 , left:244
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:108 , right:512 , bottom:324 , left:296
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 2 at top:264 , right:124 , bottom:336 , left:52
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:464 , bottom:324 , left:248
# Found face 1 at top:108 , right:464 , bottom:324 , left:248
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:512 , bottom:324 , left:296
# Found face 1 at top:108 , right:536 , bottom:324 , left:320
# Found face 1 at top:108 , right:536 , bottom:324 , left:320
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:488 , bottom:348 , left:272
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 2 at top:48 , right:248 , bottom:228 , left:68
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 2 at top:228 , right:248 , bottom:408 , left:68
# Found face 1 at top:104 , right:532 , bottom:360 , left:272
# Found face 2 at top:248 , right:208 , bottom:428 , left:28
# Found face 1 at top:248 , right:188 , bottom:428 , left:8
# Found face 2 at top:104 , right:532 , bottom:360 , left:272
# Found face 1 at top:248 , right:188 , bottom:428 , left:8
# Found face 2 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:248 , right:168 , bottom:428 , left:0
# Found face 2 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 2 at top:268 , right:168 , bottom:448 , left:0
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 2 at top:268 , right:168 , bottom:448 , left:0
# Found face 1 at top:108 , right:512 , bottom:324 , left:296
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:108 , right:488 , bottom:324 , left:272
# Found face 1 at top:76 , right:472 , bottom:332 , left:216
# Found face 1 at top:88 , right:228 , bottom:268 , left:48
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:532 , bottom:388 , left:272
# Found face 1 at top:132 , right:464 , bottom:348 , left:248
# Found face 1 at top:212 , right:208 , bottom:316 , left:104
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:188 , right:388 , bottom:448 , left:128
# Found face 1 at top:188 , right:444 , bottom:448 , left:188
# Found face 1 at top:160 , right:416 , bottom:420 , left:156
# Found face 1 at top:132 , right:416 , bottom:388 , left:156
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:104 , right:444 , bottom:360 , left:188
# Found face 1 at top:104 , right:444 , bottom:360 , left:188
# Found face 1 at top:104 , right:444 , bottom:360 , left:188
# Found face 1 at top:104 , right:444 , bottom:360 , left:188
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:92 , right:468 , bottom:400 , left:156
# Found face 1 at top:104 , right:444 , bottom:360 , left:188
# Found face 1 at top:132 , right:444 , bottom:388 , left:188
# Found face 1 at top:188 , right:416 , bottom:448 , left:156
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:500 , bottom:436 , left:192
# Found face 1 at top:160 , right:472 , bottom:420 , left:216
# Found face 1 at top:124 , right:500 , bottom:436 , left:192
# Found face 1 at top:124 , right:500 , bottom:436 , left:192
# Found face 1 at top:160 , right:472 , bottom:420 , left:216
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:500 , bottom:436 , left:192
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:500 , bottom:436 , left:192
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:160 , right:444 , bottom:420 , left:188
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:124 , right:468 , bottom:436 , left:156
# Found face 1 at top:160 , right:532 , bottom:420 , left:272
# Found face 1 at top:160 , right:500 , bottom:420 , left:244
# Found face 1 at top:160 , right:500 , bottom:468 , left:192
# Found face 1 at top:288 , right:524 , bottom:468 , left:344
# Found face 1 at top:16 , right:388 , bottom:276 , left:128
# Found face 1 at top:60 , right:368 , bottom:276 , left:152
# Found face 1 at top:84 , right:344 , bottom:300 , left:128
# Found face 1 at top:84 , right:344 , bottom:300 , left:128
# Found face 1 at top:84 , right:344 , bottom:300 , left:128
# Found face 1 at top:84 , right:344 , bottom:300 , left:128
